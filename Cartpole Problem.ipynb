# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8911090557802088, score: 43
# Scores: (min: 43, avg: 43, max: 43)
#
# Run: 2, exploration: 0.8475428503023453, score: 11
# Scores: (min: 11, avg: 27, max: 43)
#
# Run: 3, exploration: 0.7861544476842928, score: 16
# Scores: (min: 11, avg: 23.333333333333332, max: 43)
#
# Run: 4, exploration: 0.7328768546436799, score: 15
# Scores: (min: 11, avg: 21.25, max: 43)
#
# Run: 5, exploration: 0.6730128848950395, score: 18
# Scores: (min: 11, avg: 20.6, max: 43)
#
# Run: 6, exploration: 0.6305556603555866, score: 14
# Scores: (min: 11, avg: 19.5, max: 43)
#
# Run: 7, exploration: 0.5848838636585911, score: 16
# Scores: (min: 11, avg: 19, max: 43)
#
# Run: 8, exploration: 0.5535075230322891, score: 12
# Scores: (min: 11, avg: 18.125, max: 43)
#
# Run: 9, exploration: 0.5238143793828016, score: 12
# Scores: (min: 11, avg: 17.444444444444443, max: 43)
#
# Run: 10, exploration: 0.49571413690105054, score: 12
# Scores: (min: 11, avg: 16.9, max: 43)
#
# Run: 11, exploration: 0.457510005540005, score: 17
# Scores: (min: 11, avg: 16.90909090909091, max: 43)
#
# Run: 12, exploration: 0.4180382776616619, score: 19
# Scores: (min: 11, avg: 17.083333333333332, max: 43)
#
# Run: 13, exploration: 0.37251769488706843, score: 24
# Scores: (min: 11, avg: 17.615384615384617, max: 43)
#
# Run: 14, exploration: 0.2662522686041882, score: 68
# Scores: (min: 11, avg: 21.214285714285715, max: 68)
#
# Run: 15, exploration: 0.2211807388415433, score: 38
# Scores: (min: 11, avg: 22.333333333333332, max: 68)
#
# Run: 16, exploration: 0.12365869841532712, score: 117
# Scores: (min: 11, avg: 28.25, max: 117)
#
# Run: 17, exploration: 0.10221196540767843, score: 39
# Scores: (min: 11, avg: 28.88235294117647, max: 117)
#
# Run: 18, exploration: 0.08619587539414532, score: 35
# Scores: (min: 11, avg: 29.22222222222222, max: 117)
#
# Run: 19, exploration: 0.051178420962124486, score: 105
# Scores: (min: 11, avg: 33.21052631578947, max: 117)
#
# Run: 20, exploration: 0.03884689602888724, score: 56
# Scores: (min: 11, avg: 34.35, max: 117)
#
# Run: 21, exploration: 0.03131473892591842, score: 44
# Scores: (min: 11, avg: 34.80952380952381, max: 117)
#
# Run: 22, exploration: 0.01954872266561937, score: 95
# Scores: (min: 11, avg: 37.54545454545455, max: 117)
#
# Run: 23, exploration: 0.013558238831322046, score: 74
# Scores: (min: 11, avg: 39.130434782608695, max: 117)
#
# Run: 24, exploration: 0.01, score: 80
# Scores: (min: 11, avg: 40.833333333333336, max: 117)
#
# Run: 25, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 41.76, max: 117)
#
# Run: 26, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 43.34615384615385, max: 117)
#
# Run: 27, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 43.851851851851855, max: 117)
#
# Run: 28, exploration: 0.01, score: 121
# Scores: (min: 11, avg: 46.607142857142854, max: 121)
#
# Run: 29, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 47.86206896551724, max: 121)
#
# Run: 30, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 50.7, max: 133)
#
# Run: 31, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 53.483870967741936, max: 137)
#
# Run: 32, exploration: 0.01, score: 314
# Scores: (min: 11, avg: 61.625, max: 314)
#
# Run: 33, exploration: 0.01, score: 383
# Scores: (min: 11, avg: 71.36363636363636, max: 383)
#
# Run: 34, exploration: 0.01, score: 206
# Scores: (min: 11, avg: 75.32352941176471, max: 383)
#
# Run: 35, exploration: 0.01, score: 460
# Scores: (min: 11, avg: 86.31428571428572, max: 460)
#
# Run: 36, exploration: 0.01, score: 239
# Scores: (min: 11, avg: 90.55555555555556, max: 460)
#
# Run: 37, exploration: 0.01, score: 221
# Scores: (min: 11, avg: 94.08108108108108, max: 460)
#
# Run: 38, exploration: 0.01, score: 225
# Scores: (min: 11, avg: 97.52631578947368, max: 460)
#
# Run: 39, exploration: 0.01, score: 244
# Scores: (min: 11, avg: 101.28205128205128, max: 460)
#
# Run: 40, exploration: 0.01, score: 257
# Scores: (min: 11, avg: 105.175, max: 460)
#
# Run: 41, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 107.39024390243902, max: 460)
#
# Run: 42, exploration: 0.01, score: 225
# Scores: (min: 11, avg: 110.19047619047619, max: 460)
#
# Run: 43, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 112.55813953488372, max: 460)
#
# Run: 44, exploration: 0.01, score: 239
# Scores: (min: 11, avg: 115.43181818181819, max: 460)
#
# Run: 45, exploration: 0.01, score: 274
# Scores: (min: 11, avg: 118.95555555555555, max: 460)
#
# Run: 46, exploration: 0.01, score: 259
# Scores: (min: 11, avg: 122, max: 460)
#
# Run: 47, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 123.2127659574468, max: 460)
#
# Run: 48, exploration: 0.01, score: 262
# Scores: (min: 11, avg: 126.10416666666667, max: 460)
#
# Run: 49, exploration: 0.01, score: 205
# Scores: (min: 11, avg: 127.71428571428571, max: 460)
#
# Run: 50, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 129.24, max: 460)
#
# Run: 51, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 129.84313725490196, max: 460)
#
# Run: 52, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 131.03846153846155, max: 460)
#
# Run: 53, exploration: 0.01, score: 234
# Scores: (min: 11, avg: 132.9811320754717, max: 460)
#
# Run: 54, exploration: 0.01, score: 180
# Scores: (min: 11, avg: 133.85185185185185, max: 460)
#
# Run: 55, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 134.36363636363637, max: 460)
#
# Run: 56, exploration: 0.01, score: 264
# Scores: (min: 11, avg: 136.67857142857142, max: 460)
#
# Run: 57, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 138.17543859649123, max: 460)
#
# Run: 58, exploration: 0.01, score: 275
# Scores: (min: 11, avg: 140.5344827586207, max: 460)
#
# Run: 59, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 141.4406779661017, max: 460)
#
# Run: 60, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 141.31666666666666, max: 460)
#
# Run: 61, exploration: 0.01, score: 180
# Scores: (min: 11, avg: 141.95081967213116, max: 460)
#
# Run: 62, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 142.1290322580645, max: 460)
#
# Run: 63, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 142.12698412698413, max: 460)
#
# Run: 64, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 141.109375, max: 460)
#
# Run: 65, exploration: 0.01, score: 236
# Scores: (min: 11, avg: 142.56923076923076, max: 460)
#
# Run: 66, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 142.66666666666666, max: 460)
#
# Run: 67, exploration: 0.01, score: 296
# Scores: (min: 11, avg: 144.955223880597, max: 460)
#
# Run: 68, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 144.9558823529412, max: 460)
#
# Run: 69, exploration: 0.01, score: 184
# Scores: (min: 11, avg: 145.52173913043478, max: 460)
#
# Run: 70, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 145.54285714285714, max: 460)
#
# Run: 71, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 145.67605633802816, max: 460)
#
# Run: 72, exploration: 0.01, score: 201
# Scores: (min: 11, avg: 146.44444444444446, max: 460)
#
# Run: 73, exploration: 0.01, score: 173
# Scores: (min: 11, avg: 146.8082191780822, max: 460)
#
# Run: 74, exploration: 0.01, score: 168
# Scores: (min: 11, avg: 147.09459459459458, max: 460)
#
# Run: 75, exploration: 0.01, score: 168
# Scores: (min: 11, avg: 147.37333333333333, max: 460)
#
# Run: 76, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 147.28947368421052, max: 460)
#
# Run: 77, exploration: 0.01, score: 193
# Scores: (min: 11, avg: 147.88311688311688, max: 460)
#
# Run: 78, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 148.21794871794873, max: 460)
#
# Run: 79, exploration: 0.01, score: 391
# Scores: (min: 11, avg: 151.29113924050634, max: 460)
#
# Run: 80, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 155.65, max: 500)
#
# Run: 81, exploration: 0.01, score: 219
# Scores: (min: 11, avg: 156.4320987654321, max: 500)
#
# Run: 82, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 156.3170731707317, max: 500)
#
# Run: 83, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 160.4578313253012, max: 500)
#
# Run: 84, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 160.39285714285714, max: 500)
#
# Run: 85, exploration: 0.01, score: 265
# Scores: (min: 11, avg: 161.6235294117647, max: 500)
#
# Run: 86, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 165.5581395348837, max: 500)
#
# Run: 87, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 165.39080459770116, max: 500)
#
# Run: 88, exploration: 0.01, score: 239
# Scores: (min: 11, avg: 166.22727272727272, max: 500)
# Run: 89, exploration: 0.01, score: 240
# Scores: (min: 11, avg: 167.0561797752809, max: 500)
#
# Run: 90, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 166.53333333333333, max: 500)
#
# Run: 91, exploration: 0.01, score: 121
# Scores: (min: 11, avg: 166.03296703296704, max: 500)
#
# Run: 92, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 169.66304347826087, max: 500)
#
# Run: 93, exploration: 0.01, score: 47
# Scores: (min: 11, avg: 168.34408602150538, max: 500)
#
# Run: 94, exploration: 0.01, score: 220
# Scores: (min: 11, avg: 168.89361702127658, max: 500)
#
# Run: 95, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 168.6421052631579, max: 500)
#
# Run: 96, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 168.5625, max: 500)
#
# Run: 97, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 168.09278350515464, max: 500)
#
# Run: 98, exploration: 0.01, score: 62
# Scores: (min: 11, avg: 167.01020408163265, max: 500)
#
# Run: 99, exploration: 0.01, score: 252
# Scores: (min: 11, avg: 167.86868686868686, max: 500)
#
# Run: 100, exploration: 0.01, score: 177
# Scores: (min: 11, avg: 167.96, max: 500)
#
# Run: 101, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 169.07, max: 500)
#
# Run: 102, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 170.52, max: 500)
#
# Run: 103, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 171.48, max: 500)
#
# Run: 104, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 176.33, max: 500)
#
# Run: 105, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 177.73, max: 500)
#
# Run: 106, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 179.04, max: 500)
#
# Run: 107, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 180.04, max: 500)
#
# Run: 108, exploration: 0.01, score: 285
# Scores: (min: 12, avg: 182.77, max: 500)
#
# Run: 109, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 187.65, max: 500)
#
# Run: 110, exploration: 0.01, score: 259
# Scores: (min: 17, avg: 190.12, max: 500)
#
# Run: 111, exploration: 0.01, score: 282
# Scores: (min: 19, avg: 192.77, max: 500)
#
# Run: 112, exploration: 0.01, score: 478
# Scores: (min: 24, avg: 197.36, max: 500)
#
# Solved in 12 runs, 112 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
GAMMA = 0.875  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.9416228069143757, score: 13
# Scores: (min: 13, avg: 16, max: 19)
#
# Run: 3, exploration: 0.8822202429488013, score: 14
# Scores: (min: 13, avg: 15.333333333333334, max: 19)
#
# Run: 4, exploration: 0.7940753492934954, score: 22
# Scores: (min: 13, avg: 17, max: 22)
#
# Run: 5, exploration: 0.736559652908221, score: 16
# Scores: (min: 13, avg: 16.8, max: 22)
#
# Run: 6, exploration: 0.6629680834613705, score: 22
# Scores: (min: 13, avg: 17.666666666666668, max: 22)
#
# Run: 7, exploration: 0.6305556603555866, score: 11
# Scores: (min: 11, avg: 16.714285714285715, max: 22)
#
# Run: 8, exploration: 0.5819594443402982, score: 17
# Scores: (min: 11, avg: 16.75, max: 22)
#
# Run: 9, exploration: 0.4982051627146237, score: 32
# Scores: (min: 11, avg: 18.444444444444443, max: 32)
#
# Run: 10, exploration: 0.3877593341372176, score: 51
# Scores: (min: 11, avg: 21.7, max: 51)
#
# Run: 11, exploration: 0.3079101286968243, score: 47
# Scores: (min: 11, avg: 24, max: 51)
#
# Run: 12, exploration: 0.2507092085103961, score: 42
# Scores: (min: 11, avg: 25.5, max: 51)
#
# Run: 13, exploration: 0.1662122034722543, score: 83
# Scores: (min: 11, avg: 29.923076923076923, max: 83)
#
# Run: 14, exploration: 0.11470197137452155, score: 75
# Scores: (min: 11, avg: 33.142857142857146, max: 83)
#
# Run: 15, exploration: 0.07719590465791494, score: 80
# Scores: (min: 11, avg: 36.266666666666666, max: 83)
#
# Run: 16, exploration: 0.06254083169574957, score: 43
# Scores: (min: 11, avg: 36.6875, max: 83)
#
# Run: 17, exploration: 0.05092252885731386, score: 42
# Scores: (min: 11, avg: 37, max: 83)
#
# Run: 18, exploration: 0.032924408985721944, score: 88
# Scores: (min: 11, avg: 39.833333333333336, max: 88)
#
# Run: 19, exploration: 0.024991218342344988, score: 56
# Scores: (min: 11, avg: 40.68421052631579, max: 88)
#
# Run: 20, exploration: 0.011723913930325095, score: 152
# Scores: (min: 11, avg: 46.25, max: 152)
#
# Run: 21, exploration: 0.01, score: 181
# Scores: (min: 11, avg: 52.666666666666664, max: 181)
#
# Run: 22, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 57.54545454545455, max: 181)
#
# Run: 23, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 60.52173913043478, max: 181)
#
# Run: 24, exploration: 0.01, score: 129
# Scores: (min: 11, avg: 63.375, max: 181)
#
# Run: 25, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 64.8, max: 181)
#
# Run: 26, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 66.34615384615384, max: 181)
#
# Run: 27, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 67.5925925925926, max: 181)
#
# Run: 28, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 71.10714285714286, max: 181)
#
# Run: 29, exploration: 0.01, score: 200
# Scores: (min: 11, avg: 75.55172413793103, max: 200)
#
# Run: 30, exploration: 0.01, score: 184
# Scores: (min: 11, avg: 79.16666666666667, max: 200)
#
# Run: 31, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 81.51612903225806, max: 200)
#
# Run: 32, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 83.53125, max: 200)
#
# Run: 33, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 85.15151515151516, max: 200)
#
# Run: 34, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 86.88235294117646, max: 200)
#
# Run: 35, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 89.08571428571429, max: 200)
#
# Run: 36, exploration: 0.01, score: 163
# Scores: (min: 11, avg: 91.13888888888889, max: 200)
#
# Run: 37, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 92.78378378378379, max: 200)
#
# Run: 38, exploration: 0.01, score: 62
# Scores: (min: 11, avg: 91.97368421052632, max: 200)
#
# Run: 39, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 93.02564102564102, max: 200)
#
# Run: 40, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 94.1, max: 200)
#
# Run: 41, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 95.82926829268293, max: 200)
#
# Run: 42, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 97.52380952380952, max: 200)
#
# Run: 43, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 98.83720930232558, max: 200)
#
# Run: 44, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 99.47727272727273, max: 200)
#
# Run: 45, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 100.64444444444445, max: 200)
#
# Run: 46, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 101.52173913043478, max: 200)
#
# Run: 47, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 102.31914893617021, max: 200)
#
# Run: 48, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 101.08333333333333, max: 200)
#
# Run: 49, exploration: 0.01, score: 223
# Scores: (min: 11, avg: 103.57142857142857, max: 223)
#
# Run: 50, exploration: 0.01, score: 185
# Scores: (min: 11, avg: 105.2, max: 223)
#
# Run: 51, exploration: 0.01, score: 208
# Scores: (min: 11, avg: 107.2156862745098, max: 223)
#
# Run: 52, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 105.34615384615384, max: 223)
#
# Run: 53, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 105.9622641509434, max: 223)
#
# Run: 54, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 104.31481481481481, max: 223)
#
# Run: 55, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 105.21818181818182, max: 223)
#
# Run: 56, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 105.91071428571429, max: 223)
#
# Run: 57, exploration: 0.01, score: 229
# Scores: (min: 10, avg: 108.0701754385965, max: 229)
#
# Run: 58, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 107.70689655172414, max: 229)
#
# Run: 59, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 108.69491525423729, max: 229)
#
# Run: 60, exploration: 0.01, score: 218
# Scores: (min: 10, avg: 110.51666666666667, max: 229)
#
# Run: 61, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 111.19672131147541, max: 229)
#
# Run: 62, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 110.95161290322581, max: 229)
#
# Run: 63, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 110.77777777777777, max: 229)
#
# Run: 64, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 111.46875, max: 229)
#
# Run: 65, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 110.04615384615384, max: 229)
#
# Run: 66, exploration: 0.01, score: 332
# Scores: (min: 10, avg: 113.4090909090909, max: 332)
#
# Run: 67, exploration: 0.01, score: 270
# Scores: (min: 10, avg: 115.74626865671642, max: 332)
#
# Run: 68, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 115.91176470588235, max: 332)
#
# Run: 69, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 116.82608695652173, max: 332)
#
# Run: 70, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 117.48571428571428, max: 332)
#
# Run: 71, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 118.61971830985915, max: 332)
#
# Run: 72, exploration: 0.01, score: 297
# Scores: (min: 10, avg: 121.09722222222223, max: 332)
#
# Run: 73, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 121.78082191780823, max: 332)
#
# Run: 74, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 122.72972972972973, max: 332)
#
# Run: 75, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 123.38666666666667, max: 332)
#
# Run: 76, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 124, max: 332)
#
# Run: 77, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 125.06493506493507, max: 332)
#
# Run: 78, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 126.35897435897436, max: 332)
#
# Run: 79, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 127.41772151898734, max: 332)
#
# Run: 80, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 127.25, max: 332)
#
# Run: 81, exploration: 0.01, score: 338
# Scores: (min: 10, avg: 129.85185185185185, max: 338)
#
# Run: 82, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 130.67073170731706, max: 338)
#
# Run: 83, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 131.04819277108433, max: 338)
#
# Run: 84, exploration: 0.01, score: 234
# Scores: (min: 10, avg: 132.27380952380952, max: 338)
#
# Run: 85, exploration: 0.01, score: 234
# Scores: (min: 10, avg: 133.47058823529412, max: 338)
#
# Run: 86, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 133.34883720930233, max: 338)
#
# Run: 87, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 134.02298850574712, max: 338)
#
# Run: 88, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 134.72727272727272, max: 338)
#
# Run: 89, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 135.67415730337078, max: 338)
# Run: 90, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 135.64444444444445, max: 338)
#
# Run: 91, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 136.56043956043956, max: 338)
#
# Run: 92, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 137.2608695652174, max: 338)
#
# Run: 93, exploration: 0.01, score: 237
# Scores: (min: 10, avg: 138.33333333333334, max: 338)
#
# Run: 94, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 138.5744680851064, max: 338)
#
# Run: 95, exploration: 0.01, score: 281
# Scores: (min: 10, avg: 140.07368421052632, max: 338)
#
# Run: 96, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 140.14583333333334, max: 338)
#
# Run: 97, exploration: 0.01, score: 229
# Scores: (min: 10, avg: 141.06185567010309, max: 338)
#
# Run: 98, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 142.40816326530611, max: 338)
#
# Run: 99, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 142.67676767676767, max: 338)
#
# Run: 100, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 142.72, max: 338)
#
# Run: 101, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 144.21, max: 338)
#
# Run: 102, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 146.54, max: 338)
#
# Run: 103, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 148.09, max: 338)
#
# Run: 104, exploration: 0.01, score: 404
# Scores: (min: 10, avg: 151.91, max: 404)
#
# Run: 105, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 156.75, max: 500)
#
# Run: 106, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 158.07, max: 500)
#
# Run: 107, exploration: 0.01, score: 360
# Scores: (min: 10, avg: 161.56, max: 500)
#
# Run: 108, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 163.23, max: 500)
#
# Run: 109, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 164.28, max: 500)
#
# Run: 110, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 168.77, max: 500)
#
# Run: 111, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 168.9, max: 500)
#
# Run: 112, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 169.74, max: 500)
#
# Run: 113, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 170.78, max: 500)
#
# Run: 114, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 172.19, max: 500)
#
# Run: 115, exploration: 0.01, score: 453
# Scores: (min: 10, avg: 175.92, max: 500)
#
# Run: 116, exploration: 0.01, score: 351
# Scores: (min: 10, avg: 179, max: 500)
#
# Run: 117, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 179.88, max: 500)
#
# Run: 118, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 180.93, max: 500)
#
# Run: 119, exploration: 0.01, score: 280
# Scores: (min: 10, avg: 183.17, max: 500)
#
# Run: 120, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 182.13, max: 500)
#
# Run: 121, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 181.6, max: 500)
#
# Run: 122, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 181.26, max: 500)
#
# Run: 123, exploration: 0.01, score: 274
# Scores: (min: 10, avg: 182.74, max: 500)
#
# Run: 124, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 183.25, max: 500)
#
# Run: 125, exploration: 0.01, score: 233
# Scores: (min: 10, avg: 184.59, max: 500)
#
# Run: 126, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 185.97, max: 500)
#
# Run: 127, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 187.19, max: 500)
#
# Run: 128, exploration: 0.01, score: 213
# Scores: (min: 10, avg: 187.66, max: 500)
#
# Run: 129, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 188.39, max: 500)
#
# Run: 130, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 188.77, max: 500)
#
# Run: 131, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 188.68, max: 500)
#
# Run: 132, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 189.05, max: 500)
#
# Run: 133, exploration: 0.01, score: 283
# Scores: (min: 10, avg: 190.51, max: 500)
#
# Run: 134, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 191.04, max: 500)
#
# Run: 135, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 194.4, max: 500)
#
# Run: 136, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 194.37, max: 500)
#
# Run: 137, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 194.59, max: 500)
#
# Run: 138, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 196.33, max: 500)
#
# Solved in 38 runs, 138 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ceb25029292d> in <module>
#       9 EXPLORATION_DECAY = 0.995
#      10
# ---> 11 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
GAMMA = 0.95  
LEARNING_RATE = 0.0015  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.9229311239742362, score: 17
# Scores: (min: 17, avg: 18, max: 19)
#
# Run: 3, exploration: 0.8020760579717637, score: 29
# Scores: (min: 17, avg: 21.666666666666668, max: 29)
#
# Run: 4, exploration: 0.7744209942832988, score: 8
# Scores: (min: 8, avg: 18.25, max: 29)
#
# Run: 5, exploration: 0.7183288830986236, score: 16
# Scores: (min: 8, avg: 17.8, max: 29)
#
# Run: 6, exploration: 0.6662995813682115, score: 16
# Scores: (min: 8, avg: 17.5, max: 29)
#
# Run: 7, exploration: 0.5878229785513479, score: 26
# Scores: (min: 8, avg: 18.714285714285715, max: 29)
#
# Run: 8, exploration: 0.5590843898207511, score: 11
# Scores: (min: 8, avg: 17.75, max: 29)
#
# Run: 9, exploration: 0.5211953074858876, score: 15
# Scores: (min: 8, avg: 17.444444444444443, max: 29)
#
# Run: 10, exploration: 0.49571413690105054, score: 11
# Scores: (min: 8, avg: 16.8, max: 29)
#
# Run: 11, exploration: 0.4417353564707963, score: 24
# Scores: (min: 8, avg: 17.454545454545453, max: 29)
#
# Run: 12, exploration: 0.3819719776053028, score: 30
# Scores: (min: 8, avg: 18.5, max: 30)
#
# Run: 13, exploration: 0.36512303261753626, score: 10
# Scores: (min: 8, avg: 17.846153846153847, max: 30)
#
# Run: 14, exploration: 0.3507711574848344, score: 9
# Scores: (min: 8, avg: 17.214285714285715, max: 30)
#
# Run: 15, exploration: 0.33195389135223546, score: 12
# Scores: (min: 8, avg: 16.866666666666667, max: 30)
#
# Run: 16, exploration: 0.32050833588933575, score: 8
# Scores: (min: 8, avg: 16.3125, max: 30)
#
# Run: 17, exploration: 0.3079101286968243, score: 9
# Scores: (min: 8, avg: 15.882352941176471, max: 30)
#
# Run: 18, exploration: 0.2943280830920294, score: 10
# Scores: (min: 8, avg: 15.555555555555555, max: 30)
#
# Run: 19, exploration: 0.2827589419554058, score: 9
# Scores: (min: 8, avg: 15.210526315789474, max: 30)
#
# Run: 20, exploration: 0.27164454854530906, score: 9
# Scores: (min: 8, avg: 14.9, max: 30)
#
# Run: 21, exploration: 0.25578670228422234, score: 13
# Scores: (min: 8, avg: 14.80952380952381, max: 30)
#
# Run: 22, exploration: 0.2457325055235537, score: 9
# Scores: (min: 8, avg: 14.545454545454545, max: 30)
#
# Run: 23, exploration: 0.23607350863684065, score: 9
# Scores: (min: 8, avg: 14.304347826086957, max: 30)
#
# Run: 24, exploration: 0.22229219984074702, score: 13
# Scores: (min: 8, avg: 14.25, max: 30)
#
# Run: 25, exploration: 0.20931540516921554, score: 13
# Scores: (min: 8, avg: 14.2, max: 30)
#
# Run: 26, exploration: 0.2010878536592394, score: 9
# Scores: (min: 8, avg: 14, max: 30)
#
# Run: 27, exploration: 0.192217783647157, score: 10
# Scores: (min: 8, avg: 13.851851851851851, max: 30)
#
# Run: 28, exploration: 0.182820281282489, score: 11
# Scores: (min: 8, avg: 13.75, max: 30)
#
# Run: 29, exploration: 0.17388222158237718, score: 11
# Scores: (min: 8, avg: 13.655172413793103, max: 30)
#
# Run: 30, exploration: 0.16455423674261854, score: 12
# Scores: (min: 8, avg: 13.6, max: 30)
#
# Run: 31, exploration: 0.1580861105294992, score: 9
# Scores: (min: 8, avg: 13.451612903225806, max: 30)
#
# Run: 32, exploration: 0.1518722266715875, score: 9
# Scores: (min: 8, avg: 13.3125, max: 30)
#
# Run: 33, exploration: 0.14444721332374086, score: 11
# Scores: (min: 8, avg: 13.242424242424242, max: 30)
#
# Run: 34, exploration: 0.13807558583895513, score: 10
# Scores: (min: 8, avg: 13.147058823529411, max: 30)
#
# Run: 35, exploration: 0.13198501352907185, score: 10
# Scores: (min: 8, avg: 13.057142857142857, max: 30)
#
# Run: 36, exploration: 0.12679708435358925, score: 9
# Scores: (min: 8, avg: 12.944444444444445, max: 30)
#
# Run: 37, exploration: 0.12120401149972035, score: 10
# Scores: (min: 8, avg: 12.864864864864865, max: 30)
#
# Run: 38, exploration: 0.11702497557911415, score: 8
# Scores: (min: 8, avg: 12.736842105263158, max: 30)
#
# Run: 39, exploration: 0.11242507996344034, score: 9
# Scores: (min: 8, avg: 12.64102564102564, max: 30)
#
# Run: 40, exploration: 0.10746596228306791, score: 10
# Scores: (min: 8, avg: 12.575, max: 30)
#
# Run: 41, exploration: 0.10170090558064004, score: 12
# Scores: (min: 8, avg: 12.560975609756097, max: 30)
#
# Run: 42, exploration: 0.09770335251664321, score: 9
# Scores: (min: 8, avg: 12.476190476190476, max: 30)
#
# Run: 43, exploration: 0.09386293109673778, score: 9
# Scores: (min: 8, avg: 12.395348837209303, max: 30)
#
# Run: 44, exploration: 0.089273984641318, score: 11
# Scores: (min: 8, avg: 12.363636363636363, max: 30)
#
# Run: 45, exploration: 0.08406242000238873, score: 13
# Scores: (min: 8, avg: 12.377777777777778, max: 30)
#
# Run: 46, exploration: 0.08075818212241151, score: 9
# Scores: (min: 8, avg: 12.304347826086957, max: 30)
#
# Run: 47, exploration: 0.07719590465791494, score: 10
# Scores: (min: 8, avg: 12.25531914893617, max: 30)
#
# Run: 48, exploration: 0.0745342397963533, score: 8
# Scores: (min: 8, avg: 12.166666666666666, max: 30)
#
# Run: 49, exploration: 0.0712465030521374, score: 10
# Scores: (min: 8, avg: 12.122448979591837, max: 30)
#
# Run: 50, exploration: 0.0677632708131484, score: 11
# Scores: (min: 8, avg: 12.1, max: 30)
#
# Run: 51, exploration: 0.06509970288011008, score: 9
# Scores: (min: 8, avg: 12.03921568627451, max: 30)
#
# Run: 52, exploration: 0.062228127537270826, score: 10
# Scores: (min: 8, avg: 12, max: 30)
#
# Run: 53, exploration: 0.05918580250061433, score: 11
# Scores: (min: 8, avg: 11.981132075471699, max: 30)
#
# Run: 54, exploration: 0.05714511431233153, score: 8
# Scores: (min: 8, avg: 11.907407407407407, max: 30)
#
# Run: 55, exploration: 0.05462441922520914, score: 10
# Scores: (min: 8, avg: 11.872727272727273, max: 30)
#
# Run: 56, exploration: 0.052477299559006776, score: 9
# Scores: (min: 8, avg: 11.821428571428571, max: 30)
#
# Run: 57, exploration: 0.05066791621302729, score: 8
# Scores: (min: 8, avg: 11.75438596491228, max: 30)
#
# Run: 58, exploration: 0.048432933065126825, score: 10
# Scores: (min: 8, avg: 11.724137931034482, max: 30)
#
# Run: 59, exploration: 0.046296535966244, score: 10
# Scores: (min: 8, avg: 11.694915254237289, max: 30)
#
# Run: 60, exploration: 0.04425437624418858, score: 10
# Scores: (min: 8, avg: 11.666666666666666, max: 30)
#
# Run: 61, exploration: 0.04251487140556204, score: 9
# Scores: (min: 8, avg: 11.62295081967213, max: 30)
#
# Run: 62, exploration: 0.04084374120782771, score: 9
# Scores: (min: 8, avg: 11.580645161290322, max: 30)
#
# Run: 63, exploration: 0.039435475429100995, score: 8
# Scores: (min: 8, avg: 11.523809523809524, max: 30)
#
# Run: 64, exploration: 0.0378853869148274, score: 9
# Scores: (min: 8, avg: 11.484375, max: 30)
#
# Run: 65, exploration: 0.036396227662238566, score: 9
# Scores: (min: 8, avg: 11.446153846153846, max: 30)
#
# Run: 66, exploration: 0.03479077471386296, score: 10
# Scores: (min: 8, avg: 11.424242424242424, max: 30)
#
# Run: 67, exploration: 0.03325613897196732, score: 10
# Scores: (min: 8, avg: 11.402985074626866, max: 30)
#
# Run: 68, exploration: 0.031948941366546975, score: 9
# Scores: (min: 8, avg: 11.367647058823529, max: 30)
#
# Run: 69, exploration: 0.030539660091838977, score: 10
# Scores: (min: 8, avg: 11.347826086956522, max: 30)
#
# Run: 70, exploration: 0.029192542808371146, score: 10
# Scores: (min: 8, avg: 11.32857142857143, max: 30)
#
# Run: 71, exploration: 0.0280450728002803, score: 9
# Scores: (min: 8, avg: 11.295774647887324, max: 30)
#
# Run: 72, exploration: 0.026807992814067, score: 10
# Scores: (min: 8, avg: 11.277777777777779, max: 30)
#
# Run: 73, exploration: 0.025754252208694463, score: 9
# Scores: (min: 8, avg: 11.246575342465754, max: 30)
#
# Run: 74, exploration: 0.024741930939380097, score: 9
# Scores: (min: 8, avg: 11.216216216216216, max: 30)
#
# Run: 75, exploration: 0.023650553933395897, score: 10
# Scores: (min: 8, avg: 11.2, max: 30)
#
# Run: 76, exploration: 0.022720922640519125, score: 9
# Scores: (min: 8, avg: 11.171052631578947, max: 30)
#
# Run: 77, exploration: 0.021827832324362372, score: 9
# Scores: (min: 8, avg: 11.142857142857142, max: 30)
#
# Run: 78, exploration: 0.020864997436994256, score: 10
# Scores: (min: 8, avg: 11.128205128205128, max: 30)
#
# Run: 79, exploration: 0.019944633602480003, score: 10
# Scores: (min: 8, avg: 11.113924050632912, max: 30)
#
# Run: 80, exploration: 0.019064867404770626, score: 10
# Scores: (min: 8, avg: 11.1, max: 30)
#
# Run: 81, exploration: 0.018223908064988973, score: 10
# Scores: (min: 8, avg: 11.08641975308642, max: 30)
#
# Run: 82, exploration: 0.0175075817047932, score: 9
# Scores: (min: 8, avg: 11.060975609756097, max: 30)
# Run: 83, exploration: 0.016651638319386028, score: 11
# Scores: (min: 8, avg: 11.060240963855422, max: 30)
#
# Run: 84, exploration: 0.015917127532080494, score: 10
# Scores: (min: 8, avg: 11.047619047619047, max: 30)
#
# Run: 85, exploration: 0.01529147369377279, score: 9
# Scores: (min: 8, avg: 11.023529411764706, max: 30)
#
# Run: 86, exploration: 0.01461696034160619, score: 10
# Scores: (min: 8, avg: 11.011627906976743, max: 30)
#
# Run: 87, exploration: 0.013972200057807112, score: 10
# Scores: (min: 8, avg: 11, max: 30)
#
# Run: 88, exploration: 0.013289101019874787, score: 11
# Scores: (min: 8, avg: 11, max: 30)
#
# Run: 89, exploration: 0.012513320603703188, score: 13
# Scores: (min: 8, avg: 11.02247191011236, max: 30)
#
# Run: 90, exploration: 0.011723913930325095, score: 14
# Scores: (min: 8, avg: 11.055555555555555, max: 30)
#
# Run: 91, exploration: 0.011094979641301777, score: 12
# Scores: (min: 8, avg: 11.065934065934066, max: 30)
#
# Run: 92, exploration: 0.010239902030817916, score: 17
# Scores: (min: 8, avg: 11.130434782608695, max: 30)
#
# Run: 93, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.193548387096774, max: 30)
#
# Run: 94, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.191489361702128, max: 30)
#
# Run: 95, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.210526315789474, max: 30)
#
# Run: 96, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.28125, max: 30)
#
# Run: 97, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.329896907216495, max: 30)
#
# Run: 98, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.438775510204081, max: 30)
#
# Run: 99, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 11.767676767676768, max: 44)
#
# Run: 100, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.77, max: 44)
#
# Run: 101, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.73, max: 44)
#
# Run: 102, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.67, max: 44)
#
# Run: 103, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.52, max: 44)
#
# Run: 104, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.6, max: 44)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.54, max: 44)
#
# Run: 106, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.5, max: 44)
#
# Run: 107, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.36, max: 44)
#
# Run: 108, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.37, max: 44)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.32, max: 44)
#
# Run: 110, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.35, max: 44)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.21, max: 44)
#
# Run: 112, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.05, max: 44)
#
# Run: 113, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.06, max: 44)
#
# Run: 114, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.1, max: 44)
#
# Run: 115, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.09, max: 44)
#
# Run: 116, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.13, max: 44)
#
# Run: 117, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.17, max: 44)
#
# Run: 118, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.26, max: 44)
#
# Run: 119, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.29, max: 44)
#
# Run: 120, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.37, max: 44)
#
# Run: 121, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.35, max: 44)
#
# Run: 122, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.42, max: 44)
#
# Run: 123, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.53, max: 44)
#
# Run: 124, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.56, max: 44)
#
# Run: 125, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.6, max: 44)
#
# Run: 126, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.74, max: 44)
#
# Run: 127, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.87, max: 44)
#
# Run: 128, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 12.08, max: 44)
#
# Run: 129, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.13, max: 44)
#
# Run: 130, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 12.38, max: 44)
#
# Run: 131, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.48, max: 44)
#
# Run: 132, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.54, max: 44)
#
# Run: 133, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12.69, max: 44)
#
# Run: 134, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.84, max: 44)
#
# Run: 135, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 13.05, max: 44)
#
# Run: 136, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.2, max: 44)
#
# Run: 137, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.31, max: 44)
#
# Run: 138, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.39, max: 44)
#
# Run: 139, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.54, max: 44)
#
# Run: 140, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 13.84, max: 44)
#
# Run: 141, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 14.21, max: 49)
#
# Run: 142, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.29, max: 49)
#
# Run: 143, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 14.62, max: 49)
#
# Run: 144, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.72, max: 49)
#
# Run: 145, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 15.15, max: 56)
#
# Run: 146, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 15.49, max: 56)
#
# Run: 147, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 15.98, max: 59)
#
# Run: 148, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 16.72, max: 82)
#
# Run: 149, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 17.04, max: 82)
#
# Run: 150, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 18.07, max: 114)
#
# Run: 151, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 19.34, max: 136)
#
# Run: 152, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 19.89, max: 136)
#
# Run: 153, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.02, max: 136)
#
# Run: 154, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 20.35, max: 136)
#
# Run: 155, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.44, max: 136)
#
# Run: 156, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 20.65, max: 136)
#
# Run: 157, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 20.83, max: 136)
#
# Run: 158, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 22.27, max: 154)
#
# Run: 159, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.35, max: 154)
#
# Run: 160, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 22.57, max: 154)
#
# Run: 161, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 22.74, max: 154)
#
# Run: 162, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 22.94, max: 154)
#
# Run: 163, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 27.86, max: 500)
#
# Run: 164, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 30.01, max: 500)
#
# Run: 165, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 31.81, max: 500)
#
# Run: 166, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 34.33, max: 500)
#
# Run: 167, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 36.15, max: 500)
#
# Run: 168, exploration: 0.01, score: 253
# Scores: (min: 9, avg: 38.59, max: 500)
#
# Run: 169, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 40.04, max: 500)
#
# Run: 170, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 41.46, max: 500)
#
# Run: 171, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 42.68, max: 500)
#
# Run: 172, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 43.95, max: 500)
#
# Run: 173, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 45.43, max: 500)
#
# Run: 174, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 46.79, max: 500)
#
# Run: 175, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 48.25, max: 500)
#
# Run: 176, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 49.51, max: 500)
#
# Run: 177, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 50.86, max: 500)
#
# Run: 178, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 53.47, max: 500)
#
# Run: 179, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 55.63, max: 500)
#
# Run: 180, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 56.8, max: 500)
#
# Run: 181, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 58, max: 500)
#
# Run: 182, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 59.5, max: 500)
#
# Run: 183, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 61.35, max: 500)
# Run: 184, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 63.37, max: 500)
#
# Run: 185, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 65, max: 500)
#
# Run: 186, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 66.36, max: 500)
#
# Run: 187, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 67.94, max: 500)
#
# Run: 188, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 69.5, max: 500)
#
# Run: 189, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 71.16, max: 500)
#
# Run: 190, exploration: 0.01, score: 245
# Scores: (min: 10, avg: 73.47, max: 500)
#
# Run: 191, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 74.62, max: 500)
#
# Run: 192, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 76.41, max: 500)
#
# Run: 193, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 78.25, max: 500)
#
# Run: 194, exploration: 0.01, score: 263
# Scores: (min: 10, avg: 80.77, max: 500)
#
# Run: 195, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 82.62, max: 500)
#
# Run: 196, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 84.66, max: 500)
#
# Run: 197, exploration: 0.01, score: 358
# Scores: (min: 10, avg: 88.08, max: 500)
#
# Run: 198, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 89.39, max: 500)
#
# Run: 199, exploration: 0.01, score: 383
# Scores: (min: 10, avg: 92.78, max: 500)
#
# Run: 200, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 94.09, max: 500)
#
# Run: 201, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 95.45, max: 500)
#
# Run: 202, exploration: 0.01, score: 414
# Scores: (min: 10, avg: 99.48, max: 500)
#
# Run: 203, exploration: 0.01, score: 217
# Scores: (min: 10, avg: 101.51, max: 500)
#
# Run: 204, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 101.5, max: 500)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 101.5, max: 500)
#
# Run: 206, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 102.3, max: 500)
#
# Run: 207, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 103.35, max: 500)
#
# Run: 208, exploration: 0.01, score: 452
# Scores: (min: 10, avg: 107.75, max: 500)
#
# Run: 209, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 108.81, max: 500)
#
# Run: 210, exploration: 0.01, score: 311
# Scores: (min: 10, avg: 111.78, max: 500)
#
# Run: 211, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 113.11, max: 500)
#
# Run: 212, exploration: 0.01, score: 489
# Scores: (min: 10, avg: 117.86, max: 500)
#
# Run: 213, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 117.94, max: 500)
#
# Run: 214, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 119.38, max: 500)
#
# Run: 215, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 120.47, max: 500)
#
# Run: 216, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 121.69, max: 500)
#
# Run: 217, exploration: 0.01, score: 256
# Scores: (min: 10, avg: 124.12, max: 500)
#
# Run: 218, exploration: 0.01, score: 292
# Scores: (min: 10, avg: 126.85, max: 500)
#
# Run: 219, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 128.11, max: 500)
#
# Run: 220, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 129.3, max: 500)
#
# Run: 221, exploration: 0.01, score: 256
# Scores: (min: 10, avg: 131.75, max: 500)
#
# Run: 222, exploration: 0.01, score: 486
# Scores: (min: 10, avg: 136.45, max: 500)
#
# Run: 223, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 138.34, max: 500)
#
# Run: 224, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 139.76, max: 500)
#
# Run: 225, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 141.11, max: 500)
#
# Run: 226, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 142.2, max: 500)
#
# Run: 227, exploration: 0.01, score: 283
# Scores: (min: 10, avg: 144.8, max: 500)
#
# Run: 228, exploration: 0.01, score: 204
# Scores: (min: 10, avg: 146.52, max: 500)
#
# Run: 229, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 146.47, max: 500)
#
# Run: 230, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 147.14, max: 500)
#
# Run: 231, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 148.27, max: 500)
#
# Run: 232, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 149.92, max: 500)
#
# Run: 233, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 151.13, max: 500)
#
# Run: 234, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 152.62, max: 500)
#
# Run: 235, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 154.07, max: 500)
#
# Run: 236, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 154.91, max: 500)
#
# Run: 237, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 156.66, max: 500)
#
# Run: 238, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 157.93, max: 500)
#
# Run: 239, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 157.78, max: 500)
#
# Run: 240, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 157.47, max: 500)
#
# Run: 241, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 157.07, max: 500)
#
# Run: 242, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 156.98, max: 500)
#
# Run: 243, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 156.65, max: 500)
#
# Run: 244, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 156.53, max: 500)
#
# Run: 245, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 156.07, max: 500)
#
# Run: 246, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 155.72, max: 500)
#
# Run: 247, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 155.23, max: 500)
#
# Run: 248, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 154.51, max: 500)
#
# Run: 249, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 154.19, max: 500)
#
# Run: 250, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 153.14, max: 500)
#
# Run: 251, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 151.86, max: 500)
#
# Run: 252, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 151.3, max: 500)
#
# Run: 253, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 151.16, max: 500)
#
# Run: 254, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.85, max: 500)
#
# Run: 255, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.76, max: 500)
#
# Run: 256, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 150.55, max: 500)
#
# Run: 257, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.39, max: 500)
#
# Run: 258, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 148.94, max: 500)
#
# Run: 259, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 148.85, max: 500)
#
# Run: 260, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 148.63, max: 500)
#
# Run: 261, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 148.46, max: 500)
#
# Run: 262, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 148.26, max: 500)
#
# Run: 263, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 143.34, max: 489)
#
# Run: 264, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 141.19, max: 489)
#
# Run: 265, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 139.38, max: 489)
#
# Run: 266, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 136.86, max: 489)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 135.04, max: 489)
#
# Run: 268, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 132.61, max: 489)
#
# Run: 269, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 131.15, max: 489)
#
# Run: 270, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 129.71, max: 489)
#
# Run: 271, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 128.49, max: 489)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 127.22, max: 489)
#
# Run: 273, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.75, max: 489)
#
# Run: 274, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 124.38, max: 489)
#
# Run: 275, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 122.92, max: 489)
#
# Run: 276, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 121.67, max: 489)
#
# Run: 277, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 120.32, max: 489)
#
# Run: 278, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 117.69, max: 489)
#
# Run: 279, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 115.52, max: 489)
#
# Run: 280, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 114.36, max: 489)
#
# Run: 281, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 113.15, max: 489)
#
# Run: 282, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 111.66, max: 489)
#
# Run: 283, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 109.8, max: 489)
#
# Run: 284, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 107.78, max: 489)
#
# Run: 285, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 106.16, max: 489)
# Run: 286, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 104.8, max: 489)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 103.21, max: 489)
#
# Run: 288, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 101.66, max: 489)
#
# Run: 289, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 100.22, max: 489)
#
# Run: 290, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 97.91, max: 489)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 96.73, max: 489)
#
# Run: 292, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 94.86, max: 489)
#
# Run: 293, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 92.94, max: 489)
#
# Run: 294, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 90.52, max: 489)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 88.64, max: 489)
#
# Run: 296, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.51, max: 489)
#
# Run: 297, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 83.55, max: 489)
#
# Run: 298, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 82.13, max: 489)
#
# Run: 299, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 78.82, max: 489)
#
# Run: 300, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 78.21, max: 489)
#
# Run: 301, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 77.11, max: 489)
#
# Run: 302, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 74.2, max: 489)
#
# Run: 303, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 72.41, max: 489)
#
# Run: 304, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 72.65, max: 489)
#
# Run: 305, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 72.87, max: 489)
#
# Run: 306, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 72.37, max: 489)
#
# Run: 307, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 71.54, max: 489)
#
# Run: 308, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 67.82, max: 489)
#
# Run: 309, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 67.03, max: 489)
#
# Run: 310, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 64.82, max: 489)
#
# Run: 311, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 66.16, max: 489)
#
# Run: 312, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 61.64, max: 486)
#
# Run: 313, exploration: 0.01, score: 363
# Scores: (min: 8, avg: 65.08, max: 486)
#
# Run: 314, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 64.89, max: 486)
#
# Run: 315, exploration: 0.01, score: 272
# Scores: (min: 8, avg: 66.41, max: 486)
#
# Run: 316, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 66.58, max: 486)
#
# Run: 317, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 65.61, max: 486)
#
# Run: 318, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 63.19, max: 486)
#
# Run: 319, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 63.04, max: 486)
#
# Run: 320, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 63.02, max: 486)
#
# Run: 321, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 62.03, max: 486)
#
# Run: 322, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 58.74, max: 363)
#
# Run: 323, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 58.52, max: 363)
#
# Run: 324, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 58.73, max: 363)
#
# Run: 325, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 58.4, max: 363)
#
# Run: 326, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 58.23, max: 363)
#
# Run: 327, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 55.84, max: 363)
#
# Run: 328, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 55.39, max: 363)
#
# Run: 329, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 60.28, max: 500)
#
# Run: 330, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 64.24, max: 500)
#
# Run: 331, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 64.34, max: 500)
#
# Run: 332, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 64.96, max: 500)
#
# Run: 333, exploration: 0.01, score: 420
# Scores: (min: 8, avg: 67.69, max: 500)
#
# Run: 334, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 70.95, max: 500)
#
# Run: 335, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 71.68, max: 500)
#
# Run: 336, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 73.25, max: 500)
#
# Run: 337, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 73.31, max: 500)
#
# Run: 338, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 76.88, max: 500)
#
# Run: 339, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 81.79, max: 500)
#
# Run: 340, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 86.7, max: 500)
#
# Run: 341, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 91.61, max: 500)
#
# Run: 342, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 93.65, max: 500)
#
# Run: 343, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 98.56, max: 500)
#
# Run: 344, exploration: 0.01, score: 389
# Scores: (min: 8, avg: 102.36, max: 500)
#
# Run: 345, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 107.26, max: 500)
#
# Run: 346, exploration: 0.01, score: 449
# Scores: (min: 8, avg: 111.67, max: 500)
#
# Run: 347, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 116.57, max: 500)
#
# Run: 348, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 121.47, max: 500)
#
# Run: 349, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 126.37, max: 500)
#
# Run: 350, exploration: 0.01, score: 422
# Scores: (min: 8, avg: 130.5, max: 500)
#
# Run: 351, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 135.42, max: 500)
#
# Run: 352, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 140.33, max: 500)
#
# Run: 353, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 145.23, max: 500)
#
# Run: 354, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 146.85, max: 500)
#
# Run: 355, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 146.84, max: 500)
#
# Run: 356, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 149.21, max: 500)
#
# Run: 357, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 154.11, max: 500)
#
# Run: 358, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 159.02, max: 500)
#
# Run: 359, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 160.72, max: 500)
#
# Run: 360, exploration: 0.01, score: 375
# Scores: (min: 8, avg: 164.37, max: 500)
#
# Run: 361, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 169.28, max: 500)
#
# Run: 362, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 174.19, max: 500)
#
# Run: 363, exploration: 0.01, score: 355
# Scores: (min: 8, avg: 177.66, max: 500)
#
# Run: 364, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 178.76, max: 500)
#
# Run: 365, exploration: 0.01, score: 344
# Scores: (min: 8, avg: 182.12, max: 500)
#
# Run: 366, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 183.33, max: 500)
#
# Run: 367, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 184.56, max: 500)
#
# Run: 368, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 185.55, max: 500)
#
# Run: 369, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 190.46, max: 500)
#
# Run: 370, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 191.84, max: 500)
#
# Run: 371, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 193.01, max: 500)
#
# Run: 372, exploration: 0.01, score: 428
# Scores: (min: 8, avg: 197.19, max: 500)
#
# Solved in 272 runs, 372 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cd1bd4b06bc1> in <module>
#       9 EXPLORATION_DECAY = 0.995
#      10
# ---> 11 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
GAMMA = 0.95 
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.875  

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.027177996076087403, score: 30
# Scores: (min: 17, avg: 23.5, max: 30)
#
# Run: 3, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 19, max: 30)
#
# Run: 4, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 16.75, max: 30)
#
# Run: 5, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 15.4, max: 30)
#
# Run: 6, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 16, max: 30)
#
# Run: 7, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 16.857142857142858, max: 30)
#
# Run: 8, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.75, max: 30)
#
# Run: 9, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15, max: 30)
#
# Run: 10, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.5, max: 30)
#
# Run: 11, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.909090909090908, max: 30)
#
# Run: 12, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.5, max: 30)
#
# Run: 13, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.153846153846153, max: 30)
#
# Run: 14, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.857142857142858, max: 30)
#
# Run: 15, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.6, max: 30)
#
# Run: 16, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.5, max: 30)
#
# Run: 17, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.411764705882353, max: 30)
#
# Run: 18, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.277777777777779, max: 30)
#
# Run: 19, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.210526315789474, max: 30)
#
# Run: 20, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.4, max: 30)
#
# Run: 21, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.619047619047619, max: 30)
#
# Run: 22, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.863636363636363, max: 30)
#
# Run: 23, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.043478260869565, max: 30)
#
# Run: 24, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.583333333333334, max: 30)
#
# Run: 25, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 14.56, max: 38)
#
# Run: 26, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 15.307692307692308, max: 38)
#
# Run: 27, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 15.703703703703704, max: 38)
#
# Run: 28, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 17.214285714285715, max: 58)
#
# Run: 29, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 19.379310344827587, max: 80)
#
# Run: 30, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 20.466666666666665, max: 80)
#
# Run: 31, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 21.193548387096776, max: 80)
#
# Run: 32, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 22, max: 80)
#
# Run: 33, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 22.757575757575758, max: 80)
#
# Run: 34, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 23.08823529411765, max: 80)
#
# Run: 35, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.457142857142856, max: 80)
#
# Run: 36, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.666666666666668, max: 80)
#
# Run: 37, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.2972972972973, max: 80)
#
# Run: 38, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.94736842105263, max: 80)
#
# Run: 39, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 23.435897435897434, max: 80)
#
# Run: 40, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 24.475, max: 80)
#
# Run: 41, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 24.585365853658537, max: 80)
#
# Run: 42, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 25.61904761904762, max: 80)
#
# Run: 43, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 25.697674418604652, max: 80)
#
# Run: 44, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 26.522727272727273, max: 80)
#
# Run: 45, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 27.044444444444444, max: 80)
#
# Run: 46, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 27.934782608695652, max: 80)
#
# Run: 47, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 28.595744680851062, max: 80)
#
# Run: 48, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 30.125, max: 102)
#
# Run: 49, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 31.632653061224488, max: 104)
#
# Run: 50, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 35.68, max: 234)
#
# Run: 51, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 39.03921568627451, max: 234)
#
# Run: 52, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 42.46153846153846, max: 234)
#
# Run: 53, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 44.716981132075475, max: 234)
#
# Run: 54, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 48, max: 234)
#
# Run: 55, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 51.27272727272727, max: 234)
#
# Run: 56, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 53.30357142857143, max: 234)
#
# Run: 57, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 55.50877192982456, max: 234)
#
# Run: 58, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 57.46551724137931, max: 234)
#
# Run: 59, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 59.23728813559322, max: 234)
#
# Run: 60, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 60.75, max: 234)
#
# Run: 61, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 62.14754098360656, max: 234)
#
# Run: 62, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 63.645161290322584, max: 234)
#
# Run: 63, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 65.14285714285714, max: 234)
#
# Run: 64, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 66.203125, max: 234)
#
# Run: 65, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 68.27692307692308, max: 234)
#
# Run: 66, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 68.87878787878788, max: 234)
#
# Run: 67, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 70.53731343283582, max: 234)
#
# Run: 68, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 72.1029411764706, max: 234)
#
# Run: 69, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 73.27536231884058, max: 234)
#
# Run: 70, exploration: 0.01, score: 253
# Scores: (min: 8, avg: 75.84285714285714, max: 253)
#
# Run: 71, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 77.47887323943662, max: 253)
#
# Run: 72, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 78.97222222222223, max: 253)
#
# Run: 73, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 79.93150684931507, max: 253)
#
# Run: 74, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 81.3108108108108, max: 253)
#
# Run: 75, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 82.85333333333334, max: 253)
#
# Run: 76, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 84.4342105263158, max: 253)
#
# Run: 77, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 85.46753246753246, max: 253)
#
# Run: 78, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 86.61538461538461, max: 253)
#
# Run: 79, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 87.77215189873418, max: 253)
#
# Run: 80, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 88.9, max: 253)
#
# Run: 81, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 89.77777777777777, max: 253)
#
# Run: 82, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 90.8170731707317, max: 253)
#
# Run: 83, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 91.55421686746988, max: 253)
#
# Run: 84, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 92.8452380952381, max: 253)
#
# Run: 85, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 93.92941176470588, max: 253)
#
# Run: 86, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 93.05813953488372, max: 253)
#
# Run: 87, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 95.3103448275862, max: 289)
#
# Run: 88, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 96.17045454545455, max: 289)
#
# Run: 89, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 96.93258426966293, max: 289)
#
# Run: 90, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 97.86666666666666, max: 289)
#
# Run: 91, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 98.61538461538461, max: 289)
#
# Run: 92, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 98.81521739130434, max: 289)
#
# Run: 93, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 99.61290322580645, max: 289)
#
# Run: 94, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 100.30851063829788, max: 289)
# Run: 95, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 101.4, max: 289)
#
# Run: 96, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 101.9375, max: 289)
#
# Run: 97, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 102.9381443298969, max: 289)
#
# Run: 98, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 103.71428571428571, max: 289)
#
# Run: 99, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 104.87878787878788, max: 289)
#
# Run: 100, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 105.41, max: 289)
#
# Run: 101, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 106.86, max: 289)
#
# Run: 102, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 108.48, max: 289)
#
# Run: 103, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 110.07, max: 289)
#
# Run: 104, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 111.71, max: 289)
#
# Run: 105, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 113.23, max: 289)
#
# Run: 106, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 113.17, max: 289)
#
# Run: 107, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 114.38, max: 289)
#
# Run: 108, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 115.59, max: 289)
#
# Run: 109, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 116.88, max: 289)
#
# Run: 110, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 119.09, max: 289)
#
# Run: 111, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 121.07, max: 289)
#
# Run: 112, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 122.53, max: 289)
#
# Run: 113, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 124.38, max: 289)
#
# Run: 114, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 126.47, max: 289)
#
# Run: 115, exploration: 0.01, score: 203
# Scores: (min: 10, avg: 128.41, max: 289)
#
# Run: 116, exploration: 0.01, score: 218
# Scores: (min: 10, avg: 130.48, max: 289)
#
# Run: 117, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 131.54, max: 289)
#
# Run: 118, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 132.13, max: 289)
#
# Run: 119, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 132.42, max: 289)
#
# Run: 120, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 133.93, max: 289)
#
# Run: 121, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 135.41, max: 289)
#
# Run: 122, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 136.84, max: 289)
#
# Run: 123, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 138.16, max: 289)
#
# Run: 124, exploration: 0.01, score: 205
# Scores: (min: 10, avg: 139.95, max: 289)
#
# Run: 125, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 141.35, max: 289)
#
# Run: 126, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 143.27, max: 289)
#
# Run: 127, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 144.56, max: 289)
#
# Run: 128, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 146.44, max: 289)
#
# Run: 129, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 146.98, max: 289)
#
# Run: 130, exploration: 0.01, score: 175
# Scores: (min: 10, avg: 148.21, max: 289)
#
# Run: 131, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 149.32, max: 289)
#
# Run: 132, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 150.58, max: 289)
#
# Run: 133, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 151.93, max: 289)
#
# Run: 134, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 153.69, max: 289)
#
# Run: 135, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 155.43, max: 289)
#
# Run: 136, exploration: 0.01, score: 195
# Scores: (min: 10, avg: 157.07, max: 289)
#
# Run: 137, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 158.66, max: 289)
#
# Run: 138, exploration: 0.01, score: 177
# Scores: (min: 13, avg: 160.33, max: 289)
#
# Run: 139, exploration: 0.01, score: 36
# Scores: (min: 13, avg: 160.27, max: 289)
#
# Run: 140, exploration: 0.01, score: 126
# Scores: (min: 13, avg: 160.88, max: 289)
#
# Run: 141, exploration: 0.01, score: 136
# Scores: (min: 13, avg: 161.95, max: 289)
#
# Run: 142, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 162.61, max: 289)
#
# Run: 143, exploration: 0.01, score: 210
# Scores: (min: 13, avg: 164.42, max: 289)
#
# Run: 144, exploration: 0.01, score: 161
# Scores: (min: 13, avg: 165.41, max: 289)
#
# Run: 145, exploration: 0.01, score: 186
# Scores: (min: 13, avg: 166.77, max: 289)
#
# Run: 146, exploration: 0.01, score: 213
# Scores: (min: 13, avg: 168.22, max: 289)
#
# Run: 147, exploration: 0.01, score: 138
# Scores: (min: 13, avg: 169.01, max: 289)
#
# Run: 148, exploration: 0.01, score: 140
# Scores: (min: 13, avg: 169.39, max: 289)
#
# Run: 149, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 170.26, max: 289)
#
# Run: 150, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 169.26, max: 289)
#
# Run: 151, exploration: 0.01, score: 138
# Scores: (min: 13, avg: 168.57, max: 289)
#
# Run: 152, exploration: 0.01, score: 189
# Scores: (min: 13, avg: 168.29, max: 289)
#
# Run: 153, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 168.06, max: 289)
#
# Run: 154, exploration: 0.01, score: 169
# Scores: (min: 13, avg: 167.53, max: 289)
#
# Run: 155, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 166.39, max: 289)
#
# Run: 156, exploration: 0.01, score: 93
# Scores: (min: 13, avg: 165.67, max: 289)
#
# Run: 157, exploration: 0.01, score: 148
# Scores: (min: 13, avg: 165.36, max: 289)
#
# Run: 158, exploration: 0.01, score: 178
# Scores: (min: 13, avg: 165.45, max: 289)
#
# Run: 159, exploration: 0.01, score: 182
# Scores: (min: 13, avg: 165.65, max: 289)
#
# Run: 160, exploration: 0.01, score: 155
# Scores: (min: 13, avg: 165.7, max: 289)
#
# Run: 161, exploration: 0.01, score: 200
# Scores: (min: 13, avg: 166.24, max: 289)
#
# Run: 162, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 164.8, max: 289)
#
# Run: 163, exploration: 0.01, score: 189
# Scores: (min: 11, avg: 165.11, max: 289)
#
# Run: 164, exploration: 0.01, score: 231
# Scores: (min: 11, avg: 166.09, max: 289)
#
# Run: 165, exploration: 0.01, score: 291
# Scores: (min: 11, avg: 166.99, max: 291)
#
# Run: 166, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 167.58, max: 291)
#
# Run: 167, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 167.94, max: 291)
#
# Run: 168, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 168.14, max: 291)
#
# Run: 169, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 167.83, max: 291)
#
# Run: 170, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 166.81, max: 291)
#
# Run: 171, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 165.62, max: 291)
#
# Run: 172, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 165.31, max: 291)
#
# Run: 173, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 165.38, max: 291)
#
# Run: 174, exploration: 0.01, score: 221
# Scores: (min: 11, avg: 165.77, max: 291)
#
# Run: 175, exploration: 0.01, score: 259
# Scores: (min: 11, avg: 166.39, max: 291)
#
# Run: 176, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 165.44, max: 291)
#
# Run: 177, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 165.42, max: 291)
#
# Run: 178, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 165.42, max: 291)
#
# Run: 179, exploration: 0.01, score: 201
# Scores: (min: 11, avg: 165.65, max: 291)
#
# Run: 180, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 164.05, max: 291)
#
# Run: 181, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 164.21, max: 291)
#
# Run: 182, exploration: 0.01, score: 189
# Scores: (min: 11, avg: 164.35, max: 291)
#
# Run: 183, exploration: 0.01, score: 218
# Scores: (min: 11, avg: 165.01, max: 291)
#
# Run: 184, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 164.44, max: 291)
#
# Run: 185, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 164.05, max: 291)
#
# Run: 186, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 165.62, max: 291)
#
# Run: 187, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 164.75, max: 291)
#
# Run: 188, exploration: 0.01, score: 278
# Scores: (min: 11, avg: 165.82, max: 291)
#
# Run: 189, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 165.65, max: 291)
#
# Run: 190, exploration: 0.01, score: 243
# Scores: (min: 11, avg: 166.27, max: 291)
#
# Run: 191, exploration: 0.01, score: 240
# Scores: (min: 11, avg: 167.01, max: 291)
#
# Run: 192, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 167.08, max: 291)
#
# Run: 193, exploration: 0.01, score: 282
# Scores: (min: 11, avg: 168.17, max: 291)
#
# Run: 194, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 168.11, max: 291)
# Run: 195, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 167.61, max: 291)
#
# Run: 196, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 167.58, max: 291)
#
# Run: 197, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 167.11, max: 291)
#
# Run: 198, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 167.27, max: 291)
#
# Run: 199, exploration: 0.01, score: 190
# Scores: (min: 11, avg: 166.98, max: 291)
#
# Run: 200, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 166.89, max: 291)
#
# Run: 201, exploration: 0.01, score: 203
# Scores: (min: 11, avg: 167.3, max: 291)
#
# Run: 202, exploration: 0.01, score: 233
# Scores: (min: 11, avg: 167.71, max: 291)
#
# Run: 203, exploration: 0.01, score: 177
# Scores: (min: 11, avg: 167.79, max: 291)
#
# Run: 204, exploration: 0.01, score: 178
# Scores: (min: 11, avg: 167.83, max: 291)
#
# Run: 205, exploration: 0.01, score: 207
# Scores: (min: 11, avg: 168.28, max: 291)
#
# Run: 206, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 169.6, max: 291)
#
# Run: 207, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 170.31, max: 291)
#
# Run: 208, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 170.59, max: 291)
#
# Run: 209, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 171.35, max: 291)
#
# Run: 210, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 170.96, max: 291)
#
# Run: 211, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 170.94, max: 291)
#
# Run: 212, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 171.21, max: 291)
#
# Run: 213, exploration: 0.01, score: 279
# Scores: (min: 11, avg: 172.06, max: 291)
#
# Run: 214, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 171.19, max: 291)
#
# Run: 215, exploration: 0.01, score: 203
# Scores: (min: 11, avg: 171.19, max: 291)
#
# Run: 216, exploration: 0.01, score: 187
# Scores: (min: 11, avg: 170.88, max: 291)
#
# Run: 217, exploration: 0.01, score: 199
# Scores: (min: 11, avg: 171.7, max: 291)
#
# Run: 218, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 172.68, max: 291)
#
# Run: 219, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 174.07, max: 291)
#
# Run: 220, exploration: 0.01, score: 323
# Scores: (min: 11, avg: 175.63, max: 323)
#
# Run: 221, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 175.46, max: 323)
#
# Run: 222, exploration: 0.01, score: 183
# Scores: (min: 11, avg: 175.68, max: 323)
#
# Run: 223, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 175.52, max: 323)
#
# Run: 224, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 174.92, max: 323)
#
# Run: 225, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 174.29, max: 323)
#
# Run: 226, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 173.48, max: 323)
#
# Run: 227, exploration: 0.01, score: 66
# Scores: (min: 11, avg: 172.59, max: 323)
#
# Run: 228, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 172.25, max: 323)
#
# Run: 229, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 172.93, max: 323)
#
# Run: 230, exploration: 0.01, score: 215
# Scores: (min: 11, avg: 173.33, max: 323)
#
# Run: 231, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 173.32, max: 323)
#
# Run: 232, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 172.98, max: 323)
#
# Run: 233, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 173.04, max: 323)
#
# Run: 234, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 171.08, max: 323)
#
# Run: 235, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 169.11, max: 323)
#
# Run: 236, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 168.62, max: 323)
#
# Run: 237, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 168.3, max: 323)
#
# Run: 238, exploration: 0.01, score: 211
# Scores: (min: 11, avg: 168.64, max: 323)
#
# Run: 239, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 169.46, max: 323)
#
# Run: 240, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 169.71, max: 323)
#
# Run: 241, exploration: 0.01, score: 265
# Scores: (min: 11, avg: 171, max: 323)
#
# Run: 242, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 170.73, max: 323)
#
# Run: 243, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 169.04, max: 323)
#
# Run: 244, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 167.86, max: 323)
#
# Run: 245, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 167.33, max: 323)
#
# Run: 246, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 166.5, max: 323)
#
# Run: 247, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 167.34, max: 323)
#
# Run: 248, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 166.96, max: 323)
#
# Run: 249, exploration: 0.01, score: 240
# Scores: (min: 11, avg: 167.45, max: 323)
#
# Run: 250, exploration: 0.01, score: 439
# Scores: (min: 11, avg: 170.5, max: 439)
#
# Run: 251, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 170.3, max: 439)
#
# Run: 252, exploration: 0.01, score: 265
# Scores: (min: 11, avg: 171.06, max: 439)
#
# Run: 253, exploration: 0.01, score: 324
# Scores: (min: 11, avg: 172.91, max: 439)
#
# Run: 254, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 172.6, max: 439)
#
# Run: 255, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 173.42, max: 439)
#
# Run: 256, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 174.31, max: 439)
#
# Run: 257, exploration: 0.01, score: 330
# Scores: (min: 11, avg: 176.13, max: 439)
#
# Run: 258, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 175.85, max: 439)
#
# Run: 259, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 175.14, max: 439)
#
# Run: 260, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 174.72, max: 439)
#
# Run: 261, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 177.72, max: 500)
#
# Run: 262, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 182.61, max: 500)
#
# Run: 263, exploration: 0.01, score: 288
# Scores: (min: 13, avg: 183.6, max: 500)
#
# Run: 264, exploration: 0.01, score: 402
# Scores: (min: 13, avg: 185.31, max: 500)
#
# Run: 265, exploration: 0.01, score: 239
# Scores: (min: 13, avg: 184.79, max: 500)
#
# Run: 266, exploration: 0.01, score: 354
# Scores: (min: 13, avg: 186.66, max: 500)
#
# Run: 267, exploration: 0.01, score: 203
# Scores: (min: 13, avg: 186.53, max: 500)
#
# Run: 268, exploration: 0.01, score: 238
# Scores: (min: 13, avg: 186.94, max: 500)
#
# Run: 269, exploration: 0.01, score: 163
# Scores: (min: 13, avg: 187.35, max: 500)
#
# Run: 270, exploration: 0.01, score: 100
# Scores: (min: 13, avg: 186.84, max: 500)
#
# Run: 271, exploration: 0.01, score: 334
# Scores: (min: 13, avg: 189.45, max: 500)
#
# Run: 272, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 189.58, max: 500)
#
# Run: 273, exploration: 0.01, score: 495
# Scores: (min: 13, avg: 192.97, max: 500)
#
# Run: 274, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 191.85, max: 500)
#
# Run: 275, exploration: 0.01, score: 185
# Scores: (min: 13, avg: 191.11, max: 500)
#
# Run: 276, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 191.17, max: 500)
#
# Run: 277, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 191.23, max: 500)
#
# Run: 278, exploration: 0.01, score: 249
# Scores: (min: 13, avg: 191.97, max: 500)
#
# Run: 279, exploration: 0.01, score: 209
# Scores: (min: 13, avg: 192.05, max: 500)
#
# Run: 280, exploration: 0.01, score: 150
# Scores: (min: 13, avg: 193.37, max: 500)
#
# Run: 281, exploration: 0.01, score: 249
# Scores: (min: 13, avg: 194.1, max: 500)
#
# Run: 282, exploration: 0.01, score: 420
# Scores: (min: 13, avg: 196.41, max: 500)
#
# Solved in 182 runs, 282 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e10f6dff78e7> in <module>
#       9 EXPLORATION_DECAY = 0.875
#      10
# ---> 11 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# The cartpole problem is a game in which the objective is to keep the pendulum upright. The center of gravity is located at the bottom of the pendulum to introduce instability, but it can be vertically maintained by moving the base horizontally. Therefore, the agent’s goal, in this case, is to keep the pole vertical for a specified amount of time while keeping the cart within the legal boundaries of the game. There are a multitude of states in the environment, including the position of the pole and the cart. After the cartpole game begins, each frame constitutes a new state. Subsequently, there are four measurable values within each state to include position, velocity, angle, and angular velocity (Chan, 2016). There are only two possible actions that can be performed by the agent, which are to move the cart left or right. In doing so, the cartpole problem utilizes a Markov decision process with states and rewards while leveraging Q-learning to identify the best action for a given circumstance (Surma, 2018).
#
# Experience replay is the systematic storage of past experiences and game instances for consideration in future moves. Each stored instance is comprised of the agent’s state, reward, action, the next state, and the outcome of the game (Kurban, 2019). These batches can be randomly sampled during training to identify previous actions taken and the associated results. The benefits of experience replay are described as “since the batches are composed of random experience tuples (s, a, r, s') that are out of order, the network trains better and avoids getting stuck in local minima” (Gulli & Pal, 2017). Therefore, experience replay works in this algorithm by storing past experiences to further train the model by considering past decision outcomes. Additionally, Q-learning also utilizes a discount factor, which impacts how future rewards are calculated. This value ranges from zero to one and can be modified to calculate the importance of future rewards. The impacts of the discount factor are described as “consider γ = 0.9 and a reward R = 10 that is 3 steps ahead of our current state. The importance of this reward to us from where we stand is equal to (0.9³)*10 = 7.29” (Salloum, 2018). Subsequently, the model will not be as influenced by future rewards as it is by immediate rewards.
#
# The neural network architecture that is used in this cartpole problem is comprised of three dense layers. The first layer has four input neurons and 24 output neurons. The second and third layers utilize 24 input and output neurons. Additionally, the first two layers utilize ReLU activation functions, while the third has a linear activation function. An MSE loss function accompanies the Adam optimizer for the model. The neural network makes the Q-learning algorithm more efficient by continually learning how to maximize rewards to make increasingly accurate Q-value predictions. This is done by utilizing more exploration of actions while the network is relatively untrained to tune neuron weights to increase Q-value prediction accuracy and then utilizing exploitation to determine beneficial actions to take (Gulli & Pal, 2017). In doing so, neural networks can make the Q-learning algorithm more efficient by providing the ability to approximate Q-values for current and future actions. Finally, the learning rate is the hyperparameter that defines how neuron weights will be tuned within the model. The effective implementation of a Q-learning model can be highly dependent on the sensitivity of the learning rate, which is described as "a learning rate that is too large can cause the model to converge too quickly to a suboptimal solution, whereas a learning rate that is too small can cause the process to get stuck” (Brownlee, 2020). By increasing the learning rate only slightly in the cartpole problem, the algorithm initially converged below the winning score threshold. Following this, the average score of each subsequent game instance declined rapidly before increasing once again. After more than three times the total game count of the control test, the Q-learning model with an increased learning rate was able to surpass the win criteria.
#
# References
#
# Brownlee, J. (2020, September 12). Understand the Impact of Learning Rate on Neural Network Performance. MachineLearningMastery. https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/
#
# Chan, M. (2016, November 13). Cart-Pole Balancing with Q-Learning. Medium. https://medium.com/@tuzzer/cart-pole-balancing-with-q-learning-b54c6068d947
#
# Gulli, A., & Pal, S. (2017). Deep learning with keras : Get to grips with the basics of keras to implement fast and efficient deep-learning models. Packt Publishing, Limited.
#
# Kurban, R. (2019, December 30). Deep Q Learning for the CartPole. Medium. https://towardsdatascience.com/deep-q-learning-for-the-cartpole-44d761085c2f
#
# Salloum, Z. (2018, August 29). Basics of Reinforcement Learning, the Easy Way. Medium. https://zsalloum.medium.com/basics-of-reinforcement-learning-the-easy-way-fb3a0a44f30e
#
# Surma, G. (2018, September 26). Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
